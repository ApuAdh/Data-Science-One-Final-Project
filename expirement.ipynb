# %%
import pandas as pd
from itertools import permutations

# %%
df = pd.read_csv("pokemon.csv")
generations = ['Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen1', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen2', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen3', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen4', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen5', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen6', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen7', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen8', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9', 'Gen9']
df["generation"] = generations
display(df)
# Out:
#       pokedex_id           name     type1     type2   hp  attack  defence  \
# 0              1      Bulbasaur     Grass    Poison   45      49       49
# 1              2        Ivysaur     Grass    Poison   60      62       63
# 2              3       Venusaur     Grass    Poison   80      82       83
# 3              3  Mega Venusaur     Grass    Poison   80     100      123
# 4              4     Charmander      Fire       NaN   39      52       43
# ...          ...            ...       ...       ...  ...     ...      ...
# 1190        1006   Iron Valiant     Fairy  Fighting   74     130       90
# 1191        1007       Koraidon  Fighting    Dragon  100     135      115
# 1192        1008       Miraidon  Electric    Dragon  100      85      100
# 1193        1009   Walking Wake     Water    Dragon   99      83       91
# 1194        1010    Iron Leaves     Grass   Psychic   90     130       88
#
#       special_attack  special_defence  speed generation
# ...

# %%
generations = ["Gen1", "Gen2", "Gen3", "Gen4", "Gen5", "Gen6", "Gen7", "Gen8", "Gen9"]
def GenStatAverage(gen, stat):
    filtered_df = df[df['generation'] == gen]
    stats = []
    for i in filtered_df[stat]:
        stats.append(i)
    stat_average = (sum(stats)/len(stats))
    return stat_average

list = []
for i in generations:
    list.append(GenStatAverage(i,"speed"))
print(list)
# Out:
# [73.26960784313725, 61.80357142857143, 67.38181818181818, 71.312, 68.96045197740114, 67.25, 67.77, 72.33944954128441, 75.52173913043478]

# %%
types = ['Normal', 'Fire', 'Water', 'Electric', 'Grass', 'Ice', 'Fighting', 'Poison', 'Ground',
         'Flying', 'Psychic', 'Bug', 'Rock', 'Ghost', 'Dark', 'Dragon', 'Steel', 'Fairy']

type_combinations = [a + b for i, a in enumerate(types) for b in types[i + 1:]]
for i in type_combinations:
    print(i)
# Out:
# NormalFire
# NormalWater
# NormalElectric
# NormalGrass
# NormalIce
# NormalFighting
# NormalPoison
# NormalGround
# NormalFlying
# NormalPsychic
# NormalBug
# NormalRock
# NormalGhost
# NormalDark
# NormalDragon
# NormalSteel
# NormalFairy
# FireWater
# FireElectric
# FireGrass
# FireIce
# FireFighting
# FirePoison
# FireGround
# FireFlying
# FirePsychic
# FireBug
# FireRock
# FireGhost
# FireDark
# FireDragon
# FireSteel
# FireFairy
# WaterElectric
# WaterGrass
# WaterIce
# WaterFighting
# WaterPoison
# WaterGround
# WaterFlying
# WaterPsychic
# WaterBug
# WaterRock
# WaterGhost
# WaterDark
# WaterDragon
# WaterSteel
# WaterFairy
# ElectricGrass
# ElectricIce
# ElectricFighting
# ElectricPoison
# ElectricGround
# ElectricFlying
# ElectricPsychic
# ElectricBug
# ElectricRock
# ElectricGhost
# ElectricDark
# ElectricDragon
# ElectricSteel
# ElectricFairy
# GrassIce
# GrassFighting
# GrassPoison
# GrassGround
# GrassFlying
# GrassPsychic
# GrassBug
# GrassRock
# GrassGhost
# ...
